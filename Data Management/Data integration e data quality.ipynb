# %% [markdown]
# # Integrazione dati

# %%
import json
import pandas as pd
import re
import os
from unidecode import unidecode

# %% [markdown]
# ## Import dati

# %% [markdown]
# ### Dati per mapping FBREF TM

# %%
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/")

mappa = pd.read_csv("mappa_tm_fbref.csv", encoding='latin-1')
mappa
# Out:
#        Unnamed: 0      PlayerFBref  \
# 0               1   A.J. DeLaGarza
# 1               2      AJ Marcucci
# 2               3       Aapo Halme
# 3               4  Aaron Bastiaans
# 4               5   Aaron Connolly
# ...           ...              ...
# 14398       14399       Å½an Celar
# 14399       14400   Å½an KolmaniÄ
# 14400       14401       Å½an Majer
# 14401       14402     Å½iga Frelih
# 14402       14403     Ètefan Radu
#
#                                                 UrlFBref  \
# 0      https://fbref.com/en/players/171b3c37/AJ-DeLaG...
# 1      https://fbref.com/en/players/20c86a38/AJ-Marcucci
# 2       https://fbref.com/en/players/02b952ce/Aapo-Halme
# 3      https://fbref.com/en/players/fb979733/Aaron-Ba...
# 4      https://fbref.com/en/players/27c01749/Aaron-Co...
# ...                                                  ...
# 14398    https://fbref.com/en/players/868c6958/Zan-Celar
# 14399  https://fbref.com/en/players/4501fd21/Zan-Kolm...
# ...

# %% [markdown]
# ### Dati di capology

# %%
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/capology/")

stipendi_premier = pd.read_csv("premier.csv")
stipendi_seriea = pd.read_csv("seriea.csv")
stipendi_ligue1 = pd.read_csv("ligue1.csv")
stipendi_bundesliga = pd.read_csv("bundesliga.csv")
stipendi_laliga = pd.read_csv("laliga.csv")
stipendi_mls = pd.read_csv("mls.csv")
stipendi_eredivisie = pd.read_csv("eredivisie.csv")
stipendi_liganos = pd.read_csv("liganos.csv")

# %%
# Nomi maiuscoli
stipendi_premier.name = stipendi_premier.name.str.title()
stipendi_seriea.name = stipendi_seriea.name.str.title()
stipendi_ligue1.name = stipendi_ligue1.name.str.title()
stipendi_bundesliga.name = stipendi_bundesliga.name.str.title()
stipendi_laliga.name = stipendi_laliga.name.str.title()
stipendi_mls.name = stipendi_mls.name.str.title()
stipendi_eredivisie.name = stipendi_eredivisie.name.str.title()
stipendi_liganos.name = stipendi_liganos.name.str.title()

# Nomi squadre maiuscoli
stipendi_premier.club = stipendi_premier.club.str.lower()
stipendi_seriea.club = stipendi_seriea.club.str.lower()
stipendi_ligue1.club = stipendi_ligue1.club.str.lower()
stipendi_bundesliga.club = stipendi_bundesliga.club.str.lower()
stipendi_laliga.club = stipendi_laliga.club.str.lower()
stipendi_mls.club = stipendi_mls.club.str.lower()
stipendi_eredivisie.club = stipendi_eredivisie.club.str.lower()
stipendi_liganos.club = stipendi_liganos.club.str.lower()

# %%
# colonne di interesse: annual_gross_eur, annual_net_eur, bonus_gross_eur, signed, year, total_gross_eur, total_net_eur, release_eur, position_detail, loan
# cancellare le altre (escluso name e club per il riconoscimento)

stipendi_premier = stipendi_premier.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

stipendi_seriea = stipendi_seriea.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

stipendi_ligue1 = stipendi_ligue1.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

stipendi_bundesliga = stipendi_bundesliga.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

stipendi_laliga = stipendi_laliga.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

stipendi_mls = stipendi_mls.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

stipendi_eredivisie = stipendi_eredivisie.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

stipendi_liganos = stipendi_liganos.drop(['Unnamed: 0', 'weekly_gross_eur', 'weekly_net_eur', 'weekly_gross_gbp', 
'annual_gross_gbp', 'weekly_net_gbp', 'annual_net_gbp', 'weekly_gross_usd', 'annual_gross_usd', 'weekly_net_usd', 'annual_net_usd', 
'bonus_net_eur', 'bonus_gross_gbp', 'bonus_net_gbp', 'bonus_gross_usd', 'bonus_net_usd', 'expiration', 'total_gross_gbp', 'total_net_gbp', 
'total_gross_usd', 'total_net_usd', 'release_gbp', 'release_usd', 'status', 'position', 'country', 'age', 'active'], axis=1)

# %%
stipendi_premier
# Out:
#                 name  annual_gross_eur  annual_net_eur  bonus_gross_eur  \
# 0    Kevin De Bruyne          24177321        13297527              NaN
# 1       David De Gea          22666238        12472243              NaN
# 2     Erling Haaland          22666238        12472243       28710569.0
# 3      Mohamed Salah          21155156        11635336              NaN
# 4           Casemiro          21155156        11635336        6044330.0
# ..               ...               ...             ...              ...
# 530     Levi Colwill            302217          162732              NaN
# 531     Alex Mighten            209227          116237              NaN
# 532     Jordan Smith            151108           81366              NaN
# 533  Mason Greenwood                 0               0              NaN
# 534  Sergio Reguilon                 0               0              NaN
#
#          signed  years  total_gross_eur  total_net_eur  release_eur  \
# ...

# %% [markdown]
# ### Dati di Transfermarket

# %%
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/")

market_values = pd.read_csv("market_values.csv")

# %%
# colonne di interesse: player_num, player_dob, player_height_mtrs, player_foot, date_joined, joined_from, contract_expiry, 
# player_market_value_euro

market_values = market_values.drop(['Unnamed: 0', 'region', 'season_start_year', 'player_position', 'player_age'], axis=1)
market_values.player_name = market_values.player_name.apply(unidecode)
market_values.player_name = market_values.player_name.str.title()
market_values.squad = market_values.squad.apply(unidecode)
market_values.squad = market_values.squad.str.lower()
market_values.current_club = market_values.current_club.str.lower()

# %%
market_values
# Out:
#            comp_name  country            squad player_num        player_name  \
# 0     Premier League  England  manchester city         31            Ederson
# 1     Premier League  England  manchester city         18      Stefan Ortega
# 2     Premier League  England  manchester city          -       Zack Steffen
# 3     Premier League  England  manchester city         33       Scott Carson
# 4     Premier League  England  manchester city          3         Ruben Dias
# ...              ...      ...              ...        ...                ...
# 5898       Süper Lig   Turkey     umraniyespor          -         Umut Nayir
# 5899       Süper Lig   Turkey     umraniyespor          -  Olarenwaju Kayode
# 5900       Süper Lig   Turkey     umraniyespor          -      Adel Bettaieb
# 5901       Süper Lig   Turkey     umraniyespor          -    Gunes Guventurk
# 5902       Süper Lig   Turkey     umraniyespor          -      Bugra Erdogan
#
# ...

# %%
market_values[market_values['country'] == "Italy"]
# Out:
#      comp_name country         squad player_num         player_name  \
# 1593   Serie A   Italy    ssc napoli          1          Alex Meret
# 1594   Serie A   Italy    ssc napoli          -   Pierluigi Gollini
# 1595   Serie A   Italy    ssc napoli          -    Salvatore Sirigu
# 1596   Serie A   Italy    ssc napoli         16      Hubert Idasiak
# 1597   Serie A   Italy    ssc napoli          -    Valerio Boffelli
# ...        ...     ...           ...        ...                 ...
# 2388   Serie A   Italy  uc sampdoria         23   Manolo Gabbiadini
# 2389   Serie A   Italy  uc sampdoria          -    Francesco Caputo
# 2390   Serie A   Italy  uc sampdoria         34   Daniele Montevago
# 2391   Serie A   Italy  uc sampdoria         27  Fabio Quagliarella
# 2392   Serie A   Italy  uc sampdoria          -    Mihailo Ivanovic
#
#       player_dob player_nationality           current_club  \
# 1593  1997-03-22              Italy             ssc napoli
# ...

# %% [markdown]
# ### Dati di FBREF

# %%
campionati = ['premier_2023', 'eredivisie_2023', 'liganos_2023', 'ligue1_2023', 'laliga_2023', 'bundesliga_2023', 'seriea_2023', 'mls_2023']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\andre\\OneDrive\\Documenti\\unimib\\magistrale\\primo anno\\Data Management Visualization\\data man\\prove prog'

# %%
# premier league 2023

lista_squadre = os.listdir(os.getcwd()+'/premier_2023')
premier_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/premier_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('premier_2023/', file_path)
    module_name = file_path[end.start()+len('premier_2023/'):-4]
    premier_2023[module_name] = pd.read_csv(files)

# %%
# eredivisie 2023

lista_squadre = os.listdir(os.getcwd()+'/eredivisie_2023')
eredivisie_2023 = dict() 

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/eredivisie_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]

    end = re.search('eredivisie_2023/', file_path)
    module_name = file_path[end.start()+len('eredivisie_2023/'):-4]
    eredivisie_2023[module_name] = pd.read_csv(files)

# %%
# championship_2023

lista_squadre = os.listdir(os.getcwd()+'/championship_2023')
championship_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/championship_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('championship_2023/', file_path)
    module_name = file_path[end.start()+len('championship_2023/'):-4]
    championship_2023[module_name] = pd.read_csv(files)

# %%
# liganos_2023

lista_squadre = os.listdir(os.getcwd()+'/liganos_2023')
liganos_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/liganos_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('liganos_2023/', file_path)
    module_name = file_path[end.start()+len('liganos_2023/'):-4]
    liganos_2023[module_name] = pd.read_csv(files)

# %%
# ligue1_2023

lista_squadre = os.listdir(os.getcwd()+'/ligue1_2023')
ligue1_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/ligue1_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('ligue1_2023/', file_path)
    module_name = file_path[end.start()+len('ligue1_2023/'):-4]
    ligue1_2023[module_name] = pd.read_csv(files)

# %%
# laliga_2023

lista_squadre = os.listdir(os.getcwd()+'/laliga_2023')
laliga_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/laliga_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('laliga_2023/', file_path)
    module_name = file_path[end.start()+len('laliga_2023/'):-4]
    laliga_2023[module_name] = pd.read_csv(files)

# %%
# bundesliga_2023

lista_squadre = os.listdir(os.getcwd()+'/bundesliga_2023')
bundesliga_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/bundesliga_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('bundesliga_2023/', file_path)
    module_name = file_path[end.start()+len('bundesliga_2023/'):-4]
    bundesliga_2023[module_name] = pd.read_csv(files)

# %%
# seriea_2023

lista_squadre = os.listdir(os.getcwd()+'/seriea_2023')
seriea_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/seriea_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('seriea_2023/', file_path)
    module_name = file_path[end.start()+len('seriea_2023/'):-4]
    seriea_2023[module_name] = pd.read_csv(files)

# %%
# mls_2023

lista_squadre = os.listdir(os.getcwd()+'/mls_2023')
mls_2023 = dict()

for squadra in lista_squadre:
    file_path = os.path.join(os.getcwd()+'/mls_2023/',squadra)
    start = re.search('/', file_path)
    files = file_path[start.start()+1:]
    end = re.search('mls_2023/', file_path)
    module_name = file_path[end.start()+len('mls_2023/'):-4]
    mls_2023[module_name] = pd.read_csv(files)

# %% [markdown]
# ## JOINS

# %% [markdown]
# ### Unione valori di mercato e stipendi

# %%
stipendi = pd.concat([stipendi_premier, stipendi_bundesliga, stipendi_seriea, stipendi_ligue1, stipendi_laliga, stipendi_liganos,
stipendi_eredivisie, stipendi_mls], ignore_index=True)
stipendi.name = stipendi.name.apply(unidecode)
stipendi.club = stipendi.club.apply(unidecode)
stipendi
# Out:
#                  name  annual_gross_eur  annual_net_eur  bonus_gross_eur  \
# 0     Kevin De Bruyne          24177321        13297527              NaN
# 1        David De Gea          22666238        12472243              NaN
# 2      Erling Haaland          22666238        12472243       28710569.0
# 3       Mohamed Salah          21155156        11635336              NaN
# 4            Casemiro          21155156        11635336        6044330.0
# ...               ...               ...             ...              ...
# 4488      Ilijah Paul             61612               0              NaN
# 4489       Abdi Salim             61612               0              NaN
# 4490  Herbert Endeley             61612               0              NaN
# 4491     Holden Trent             61612               0              NaN
# 4492   Maximo Carrizo             61612               0              NaN
#
#           signed  years  total_gross_eur  total_net_eur  release_eur  \
# ...

# %%
stipendi_valoremercato = pd.merge(market_values, stipendi,  how='left', left_on=['player_name'], right_on = ['name'])
duplicateRowsDF1 = stipendi_valoremercato[stipendi_valoremercato.duplicated(['player_name', 'squad'], keep='first')] # rimuovere omonimi
stipendi_valoremercato = stipendi_valoremercato.drop(duplicateRowsDF1.index)
stipendi_valoremercato
# Out:
#            comp_name  country            squad player_num        player_name  \
# 0     Premier League  England  manchester city         31            Ederson
# 2     Premier League  England  manchester city         18      Stefan Ortega
# 3     Premier League  England  manchester city          -       Zack Steffen
# 4     Premier League  England  manchester city         33       Scott Carson
# 5     Premier League  England  manchester city          3         Ruben Dias
# ...              ...      ...              ...        ...                ...
# 5994       Süper Lig   Turkey     umraniyespor          -         Umut Nayir
# 5995       Süper Lig   Turkey     umraniyespor          -  Olarenwaju Kayode
# 5996       Süper Lig   Turkey     umraniyespor          -      Adel Bettaieb
# 5997       Süper Lig   Turkey     umraniyespor          -    Gunes Guventurk
# 5998       Süper Lig   Turkey     umraniyespor          -      Bugra Erdogan
#
# ...

# %% [markdown]
# ### Unione valori di mercato e stipendi con mapping

# %%
stipendi_valoremercato = pd.merge(stipendi_valoremercato, mappa,  how='left', left_on=['player_url'], right_on = ['UrlTmarkt'])
stipendi_valoremercato = stipendi_valoremercato.drop(['Unnamed: 0', 'PlayerFBref', 'UrlTmarkt'], axis=1)
stipendi_valoremercato
# Out:
#            comp_name  country            squad player_num        player_name  \
# 0     Premier League  England  manchester city         31            Ederson
# 1     Premier League  England  manchester city         18      Stefan Ortega
# 2     Premier League  England  manchester city          -       Zack Steffen
# 3     Premier League  England  manchester city         33       Scott Carson
# 4     Premier League  England  manchester city          3         Ruben Dias
# ...              ...      ...              ...        ...                ...
# 5960       Süper Lig   Turkey     umraniyespor          -         Umut Nayir
# 5961       Süper Lig   Turkey     umraniyespor          -  Olarenwaju Kayode
# 5962       Süper Lig   Turkey     umraniyespor          -      Adel Bettaieb
# 5963       Süper Lig   Turkey     umraniyespor          -    Gunes Guventurk
# 5964       Süper Lig   Turkey     umraniyespor          -      Bugra Erdogan
#
# ...

# %% [markdown]
# ### Unione valori di mercato e stipendi con statistiche

# %%
for col in stipendi_valoremercato.columns:
    print(col)
# Out:
# comp_name
# country
# squad
# player_num
# player_name
# player_dob
# player_nationality
# current_club
# player_height_mtrs
# player_foot
# date_joined
# joined_from
# contract_expiry
# player_market_value_euro
# player_url
# name
# annual_gross_eur
# annual_net_eur
# bonus_gross_eur
# signed
# years
# total_gross_eur
# total_net_eur
# release_eur
# position_detail
# club
# loan
# UrlFBref

# %%
# rimuoviamo le variabili ripetute con i dadi di FBREF:
stipendi_valoremercato = stipendi_valoremercato.drop(['comp_name', 'country', 'squad', 'player_name', 'player_nationality', 
                                                      'name', 'club', 'position_detail'], axis=1)
stipendi_valoremercato
# Out:
#      player_num  player_dob      current_club  player_height_mtrs player_foot  \
# 0            31  1993-08-17   manchester city                1.88        left
# 1            18  1992-11-06   manchester city                1.85       right
# 2             -  1995-04-02   manchester city                1.91       right
# 3            33  1985-09-03   manchester city                1.88       right
# 4             3  1997-05-14   manchester city                1.87       right
# ...         ...         ...               ...                 ...         ...
# 5960          -  1993-06-28          eyüpspor                1.91       right
# 5961          -  1993-05-08  shakhtar donetsk                1.76       right
# 5962          -  1997-01-28      without club                1.84       right
# 5963          -  2005-07-18  ümraniyespor u19                 NaN
# 5964          -  2004-07-16  ümraniyespor u19                1.86       right
#
# ...

# %%
for squadra in bundesliga_2023:
    bundesliga_2023[squadra] = pd.merge(bundesliga_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    bundesliga_2023[squadra].Squad = bundesliga_2023[squadra].Squad.str.lower()
    bundesliga_2023[squadra] = bundesliga_2023[squadra].drop_duplicates(subset="Player")
    bundesliga_2023[squadra] = bundesliga_2023[squadra].drop(['Unnamed: 0'], axis=1)

for squadra in eredivisie_2023:
    eredivisie_2023[squadra] = pd.merge(eredivisie_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    eredivisie_2023[squadra].Squad = eredivisie_2023[squadra].Squad.str.lower()
    eredivisie_2023[squadra] = eredivisie_2023[squadra].drop_duplicates(subset="Player")
    eredivisie_2023[squadra] = eredivisie_2023[squadra].drop(['Unnamed: 0'], axis=1)

for squadra in liganos_2023:
    liganos_2023[squadra] = pd.merge(liganos_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    liganos_2023[squadra].Squad = liganos_2023[squadra].Squad.str.lower()
    liganos_2023[squadra] = liganos_2023[squadra].drop_duplicates(subset="Player")
    liganos_2023[squadra] = liganos_2023[squadra].drop(['Unnamed: 0'], axis=1)

for squadra in laliga_2023:
    laliga_2023[squadra] = pd.merge(laliga_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    laliga_2023[squadra].Squad = laliga_2023[squadra].Squad.str.lower()
    laliga_2023[squadra] = laliga_2023[squadra].drop_duplicates(subset="Player")
    laliga_2023[squadra] = laliga_2023[squadra].drop(['Unnamed: 0'], axis=1)

for squadra in ligue1_2023:
    ligue1_2023[squadra] = pd.merge(ligue1_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    ligue1_2023[squadra].Squad = ligue1_2023[squadra].Squad.str.lower()
    ligue1_2023[squadra] = ligue1_2023[squadra].drop_duplicates(subset="Player")
    ligue1_2023[squadra] = ligue1_2023[squadra].drop(['Unnamed: 0'], axis=1)

for squadra in premier_2023:
    premier_2023[squadra] = pd.merge(premier_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    premier_2023[squadra].Squad = premier_2023[squadra].Squad.str.lower()
    premier_2023[squadra] = premier_2023[squadra].drop_duplicates(subset="Player")
    premier_2023[squadra] = premier_2023[squadra].drop(['Unnamed: 0'], axis=1)

for squadra in mls_2023:
    mls_2023[squadra] = pd.merge(mls_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    mls_2023[squadra].Squad = mls_2023[squadra].Squad.str.lower()
    mls_2023[squadra] = mls_2023[squadra].drop_duplicates(subset="Player")
    mls_2023[squadra] = mls_2023[squadra].drop(['Unnamed: 0'], axis=1)

for squadra in seriea_2023:
    seriea_2023[squadra] = pd.merge(seriea_2023[squadra], stipendi_valoremercato,  how='left', left_on=['PlayerURL'], right_on = ['UrlFBref'])
    seriea_2023[squadra].Squad = seriea_2023[squadra].Squad.str.lower()
    seriea_2023[squadra] = seriea_2023[squadra].drop_duplicates(subset="Player")
    seriea_2023[squadra] = seriea_2023[squadra].drop(['Unnamed: 0'], axis=1)

# %%
seriea_2023['Milan']
# Out:
#                                             PlayerURL     Season  Squad  \
# 0   https://fbref.com/en/players/0db169ae/Sandro-T...  2022-2023  milan
# 1   https://fbref.com/en/players/16ceb862/Olivier-...  2022-2023  milan
# 2   https://fbref.com/en/players/20730eae/Rafael-Leao  2022-2023  milan
# 3   https://fbref.com/en/players/2146785a/Davide-C...  2022-2023  milan
# 4   https://fbref.com/en/players/26777636/Yacine-Adli  2022-2023  milan
# 5   https://fbref.com/en/players/2ef7c612/Charles-...  2022-2023  milan
# 6   https://fbref.com/en/players/30223b33/Antonio-...  2022-2023  milan
# 7   https://fbref.com/en/players/407feb71/Brahim-Diaz  2022-2023  milan
# 8   https://fbref.com/en/players/43a166b4/Divock-O...  2022-2023  milan
# 9   https://fbref.com/en/players/4cde5509/Zlatan-I...  2022-2023  milan
# 10   https://fbref.com/en/players/536cebe5/Ante-Rebic  2022-2023  milan
# 11  https://fbref.com/en/players/55a1cac2/Tommaso-...  2022-2023  milan
# ...

# %%
mls_2023
# Out:
# {'Atlanta United':                                             PlayerURL  Season           Squad  \
#  0   https://fbref.com/en/players/0985c282/Tyler-Wolff     NaN  atlanta united
#  1   https://fbref.com/en/players/0d5c0218/Clement-...     NaN  atlanta united
#  2   https://fbref.com/en/players/1701b012/Machop-M...     NaN  atlanta united
#  3   https://fbref.com/en/players/1835f053/Juan-Jos...     NaN  atlanta united
#  4   https://fbref.com/en/players/1cfa6e1a/Jackson-...     NaN  atlanta united
#  5    https://fbref.com/en/players/1f462f95/Luis-Abram     NaN  atlanta united
#  6   https://fbref.com/en/players/27f33438/Thiago-A...     NaN  atlanta united
#  7   https://fbref.com/en/players/43ca2019/Amar-Sejdic     NaN  atlanta united
#  8     https://fbref.com/en/players/4c46e404/Noah-Cobb     NaN  atlanta united
#  9   https://fbref.com/en/players/5480ae05/Quentin-...     NaN  atlanta united
#  10  https://fbref.com/en/players/59059f1e/Derrick-...     NaN  atlanta united
# ...

# %% [markdown]
# ## Esportare i dati

# %%
# Bundesliga
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/bundesliga/")
for squadra in bundesliga_2023:
    tabella = bundesliga_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %%
# Eredivisie
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/eredivisie/")
for squadra in eredivisie_2023:
    tabella = eredivisie_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %%
# laliga
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/laliga/")
for squadra in laliga_2023:
    tabella = laliga_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %%
 # liganos
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/liganos/")
for squadra in liganos_2023:
    tabella = liganos_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %%
# ligue1
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/ligue1/")
for squadra in ligue1_2023:
    tabella = ligue1_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %%
# mls
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/mls/")
for squadra in mls_2023:
    tabella = mls_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %%
# premier
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/premierleague/")
for squadra in premier_2023:
    tabella = premier_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %%
# seriea
os.chdir("C:/Users/andre/OneDrive/Documenti/unimib/magistrale/primo anno/Data Management Visualization/data man/prove prog/dati definitivi csv/seriea/")
for squadra in seriea_2023:
    tabella = seriea_2023.get(squadra)
    nome_squadra = squadra
    nome_file = str(nome_squadra+'.csv')
    tabella.to_csv(nome_file, encoding='utf-8')

# %% [markdown]
# # Data Quality

# %% [markdown]
# ## Completeness

# %%
diz_valori_mancanti = {}

# %%
diz_valori_mancanti_seriea = {}

for squadra in seriea_2023:
    tabella = seriea_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_seriea[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti_premier = {}

for squadra in premier_2023:
    tabella = premier_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_premier[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti_mls = {}

for squadra in mls_2023:
    tabella = mls_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_mls[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti_ligue1 = {}

for squadra in ligue1_2023:
    tabella = ligue1_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_ligue1[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti_liganos = {}

for squadra in liganos_2023:
    tabella = liganos_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_liganos[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti_laliga = {}

for squadra in laliga_2023:
    tabella = laliga_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_laliga[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti_eredivisie = {}

for squadra in eredivisie_2023:
    tabella = eredivisie_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_eredivisie[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti_bundesliga = {}

for squadra in bundesliga_2023:
    tabella = bundesliga_2023.get(squadra)
    valori_mancanti = tabella.isnull().sum().sum()
    valori_totali = tabella.shape[0]*tabella.shape[1]
    perc_valori_mancanti = valori_mancanti/valori_totali
    diz_valori_mancanti[squadra] = perc_valori_mancanti
    diz_valori_mancanti_bundesliga[squadra] = perc_valori_mancanti

# %%
diz_valori_mancanti
# Out:
# {'Atalanta': 0.2677595628415301,
#  'Bologna': 0.2181531176006314,
#  'Cremonese': 0.12796774675227715,
#  'Empoli': 0.2574842605679044,
#  'Fiorentina': 0.2070750647109577,
#  'Hellas Verona': 0.21679407548972765,
#  'Internazionale': 0.23695976154992549,
#  'Juventus': 0.21060404666962043,
#  'Lazio': 0.26067302862882974,
#  'Lecce': 0.21621621621621623,
#  'Milan': 0.13080922976925577,
#  'Monza': 0.15255009107468123,
#  'Napoli': 0.11123388581952118,
#  'Roma': 0.2933028339051976,
#  'Salernitana': 0.26449864498644987,
#  'Sampdoria': 0.1795651157353285,
#  'Sassuolo': 0.1317111459968603,
#  'Spezia': 0.2266449020592667,
#  'Torino': 0.25585585585585585,
#  'Udinese': 0.21714121368996261,
#  'Arsenal': 0.25209155485398577,
#  'Aston Villa': 0.30428530342249066,
#  'Bournemouth': 0.25828460038986356,
#  'Brentford': 0.23776223776223776,
#  'Brighton & Hove Albion': 0.17995264404104183,
#  'Chelsea': 0.19381868131868132,
#  'Crystal Palace': 0.25901639344262295,
# ...

# %%
# Livelli di table completness dei singoli dataset dei campionati
print("Livello di table completeness Serie A: ",round(sum(diz_valori_mancanti_seriea.values())/len(diz_valori_mancanti_seriea.values()), 3),"%")
print("Livello di table completeness Bundesliga: ",round(sum(diz_valori_mancanti_bundesliga.values())/len(diz_valori_mancanti_bundesliga.values()), 3),"%")
print("Livello di table completeness La Liga: ",round(sum(diz_valori_mancanti_laliga.values())/len(diz_valori_mancanti_laliga.values()), 3),"%")
print("Livello di table completeness Liga Nos: ",round(sum(diz_valori_mancanti_liganos.values())/len(diz_valori_mancanti_liganos.values()), 3),"%")
print("Livello di table completeness MLS: ",round(sum(diz_valori_mancanti_mls.values())/len(diz_valori_mancanti_mls.values()), 3),"%")
print("Livello di table completeness Ligue 1: ",round(sum(diz_valori_mancanti_ligue1.values())/len(diz_valori_mancanti_ligue1.values()), 3),"%")
print("Livello di table completeness Eredivisie: ",round(sum(diz_valori_mancanti_eredivisie.values())/len(diz_valori_mancanti_eredivisie.values()), 3),"%")
print("Livello di table completeness Premier League: ",round(sum(diz_valori_mancanti_premier.values())/len(diz_valori_mancanti_premier.values()), 3),"%")
# Out:
# Livello di table completeness Serie A:  0.209 %
# Livello di table completeness Bundesliga:  0.148 %
# Livello di table completeness La Liga:  0.19 %
# Livello di table completeness Liga Nos:  0.13 %
# Livello di table completeness MLS:  0.235 %
# Livello di table completeness Ligue 1:  0.165 %
# Livello di table completeness Eredivisie:  0.178 %
# Livello di table completeness Premier League:  0.213 %

# %%
# livello di table completness dell'intero dataset 
print("Livello di table completeness generale: ",round(sum(diz_valori_mancanti.values())/len(diz_valori_mancanti.values()), 3), "%")
# Out:
# Livello di table completeness generale:  0.187 %
