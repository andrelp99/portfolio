# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('C:\\Users\\andre\\OneDrive\\Documenti\\unimib\\Foundations computer science\\progetto')

# %%
Books_Ratings = pd.read_csv("Book-Ratings.csv", sep=";", encoding = 'latin-1')
Books_Ratings    #file Books_Ratings, con variabili User-Id, ISBN e Book-Rating. 1048575 obs
# Out:
#          User-ID        ISBN  Book-Rating
# 0         276725  034545104X            0
# 1         276726   155061224            5
# 2         276727   446520802            0
# 3         276729  052165615X            3
# 4         276729   521795028            6
# ...          ...         ...          ...
# 1048570   250764   451410777            0
# 1048571   250764   452264464            8
# 1048572   250764  048623715X            0
# 1048573   250764   486256588            0
# 1048574   250764   515069434            0
#
# [1048575 rows x 3 columns]

# %%
Books = pd.read_csv("Books.csv", sep=";", encoding = 'latin-1')
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
Books['Year-Of-Publication'].unique()
#'DK Publishing Inc' e 'Gallimard' da controllare
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#        1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#        2010, 1908, 1906, 1935, 1806, 2021, '2000', '1995', '1999', '2004',
#        '2003', '1990', '1994', '1986', '1989', '2002', '1981', '1993',
#        '1983', '1982', '1976', '1991', '1977', '1998', '1992', '1996',
#        '0', '1997', '2001', '1974', '1968', '1987', '1984', '1988',
# ...

# %%
Books.loc[Books['Year-Of-Publication'] == 'DK Publishing Inc']
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        Book-Author Year-Of-Publication  \
# 209538        2000   DK Publishing Inc
# 221678        2000   DK Publishing Inc
#
#                                                 Publisher  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-S  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-M Image-URL-L
# 209538  http://images.amazon.com/images/P/078946697X.0...         NaN
# 221678  http://images.amazon.com/images/P/0789466953.0...         NaN

# %%
Books.loc[Books['Year-Of-Publication'] == 'Gallimard']
# Out:
#               ISBN                                         Book-Title  \
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
#
#        Book-Author Year-Of-Publication  \
# 220731        2003           Gallimard
#
#                                                 Publisher  \
# 220731  http://images.amazon.com/images/P/2070426769.0...
#
#                                               Image-URL-S  \
# 220731  http://images.amazon.com/images/P/2070426769.0...
#
#                                               Image-URL-M Image-URL-L
# 220731  http://images.amazon.com/images/P/2070426769.0...         NaN

# %%
index_w_mistakes = (209538,221678,220731)
for indice in index_w_mistakes:
    title = Books['Book-Title'].loc[Books.index[indice]].partition(';')[0]
    title = title[0:-2]
    author = Books['Book-Title'].loc[Books.index[indice]].partition(';')[2]
    author = author[0:-1]
    Books.iloc[indice]['Image-URL-L'] = Books.iloc[indice]['Image-URL-M']
    Books.iloc[indice]['Image-URL-M'] = Books.iloc[indice]['Image-URL-S']
    Books.iloc[indice]['Image-URL-S'] = Books.iloc[indice]['Publisher']
    Books.iloc[indice]['Publisher'] = Books.iloc[indice]['Year-Of-Publication']
    Books.iloc[indice]['Year-Of-Publication'] = Books.iloc[indice]['Book-Author']
    Books.iloc[indice]['Book-Author'] = author
    Books.iloc[indice]['Book-Title'] = title
    print(Books.loc[Books.index[indice]])  # per verificare di aver corretto tutto, e aver traslato tutti i valori di una colonna 
                                           # verso destra da Book-Title
Books           # file Books, con variabili ISBN, Book-Title, Book-Author, Year-Of-Publication, Publisher, Image-URL-S,  
                # Image-URL-M e Image-URL-L. 271359 obs
# Out:
# ISBN                                                          078946697X
# Book-Title             DK Readers: Creating the X-Men, How It All Beg...
# Book-Author                                           Michael Teitelbaum
# Year-Of-Publication                                                 2000
# Publisher                                              DK Publishing Inc
# Image-URL-S            http://images.amazon.com/images/P/078946697X.0...
# Image-URL-M            http://images.amazon.com/images/P/078946697X.0...
# Image-URL-L            http://images.amazon.com/images/P/078946697X.0...
# Name: 209538, dtype: object
# ISBN                                                          0789466953
# Book-Title             DK Readers: Creating the X-Men, How Comic Book...
# Book-Author                                                James Buckley
# Year-Of-Publication                                                 2000
# ...

# %%
Goodbooks = pd.read_csv("goodbooks.csv", sep=",", encoding = 'latin-1')
Goodbooks                    # file Goodbooks, con variabili book_id, goodreads_book_id, best_book_id, word_id, books_count,
                             # isbn, ibsn13, authors, original_publication_year, original_title, title, language_code, 
                             # average_rating, ratings_count, work_ratings_count, work_text_reviews_count, ratings_1,
                             # ratings_2, ratings_3, ratings_4, ratings_5, image_url e small_image_url. 99 obs
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         1            2767052       2767052   2792775          272
# 1         2                  3             3   4640799          491
# 2         3              41865         41865   3212258          226
# 3         4               2657          2657   3275794          487
# 4         5               4671          4671    245494         1356
# ..      ...                ...           ...       ...          ...
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13                                    authors  \
# 0    439023483  9.780439e+12                            Suzanne Collins
# ...

# %%
Goodbooks_Ratings = pd.read_csv("goodbooks-ratings.csv", sep=",", encoding = 'latin-1')
Goodbooks_Ratings               # file Goodbooks_Ratings, con variabili user-Id, book_id e rating. 99 obs
# Out:
#     user_id  book_id  rating
# 0         1      258       5
# 1         2     4081       4
# 2         2      260       5
# 3         2     9296       5
# 4         2     2318       3
# ..      ...      ...     ...
# 94        4      184       4
# 95        4      495       4
# 96        4      350       3
# 97        4      492       4
# 98        4      219       4
#
# [99 rows x 3 columns]

# %%
Users = pd.read_csv("Users.csv", sep=";", encoding = 'latin-1')
Users               # file Users, con variabili User-Id, Location e Age. 278858 obs
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %% [markdown]
# ### **1. Normalize the location field of Users dataset, splitting into city, region, country.**

# %%
Users[['City','Region','Country']]= Users['Location'].str.split(", ", n = 2, expand = True)
Users
# Out:
#         User-ID                            Location   Age         City  \
# 0             1                  nyc, new york, usa   NaN          nyc
# 1             2           stockton, california, usa  18.0     stockton
# 2             3     moscow, yukon territory, russia   NaN       moscow
# 3             4           porto, v.n.gaia, portugal  17.0        porto
# 4             5  farnborough, hants, united kingdom   NaN  farnborough
# ...         ...                                 ...   ...          ...
# 278853   278854               portland, oregon, usa   NaN     portland
# 278854   278855  tacoma, washington, united kingdom  50.0       tacoma
# 278855   278856           brampton, ontario, canada   NaN     brampton
# 278856   278857           knoxville, tennessee, usa   NaN    knoxville
# 278857   278858                dublin, n/a, ireland   NaN       dublin
#
#                  Region         Country
# 0              new york             usa
# ...

# %% [markdown]
# ###  2. For each book in the Books dataset, compute its average rating.

# %%
medie = Books_Ratings.groupby(['ISBN'])['Book-Rating'].mean()
medie.head()                     #media dei Book-Rating, raggruppati per ISBN. Poi, inner join (ogni ISBN in Books unito alla sua media appena calcolata)
# Out:
# ISBN
#  904492401X      0.0
# #069580216X      0.0
# #6612432         5.0
# (THEWINDMILLP    0.0
# )416195113       8.0
# Name: Book-Rating, dtype: float64

# %%
pd.merge(Books, medie, how = 'inner', left_on = 'ISBN', right_on = 'ISBN')
# Out:
#              ISBN                                         Book-Title  \
# 0      074322678X            Where You'll Find Me: And Other Stories
# 1      080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2      1552041778                                           Jane Doe
# 3      1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4      1567407781       The Witchfinder (Amos Walker Mystery Series)
# ...           ...                                                ...
# 67369  8401424828                                 Hija de Homero, La
# 67370  1565120752                                       Winter Birds
# 67371  067167806X  From Winchester to Cedar Creek: The Shenandoah...
# 67372  1561709085  Inner Peace for Busy People: Simple Strategies...
# 67373  8874960018           L'Occhio Nero Al Panda Gliel'ho Fatto IO
#
#                  Book-Author Year-Of-Publication  \
# 0                Ann Beattie                2002
# ...

# %% [markdown]
# ### 3. For each book in the GoodBooks dataset, compute its average rating.

# %%
medie2 = Goodbooks_Ratings.groupby(['book_id'])['rating'].mean()
medie2.head()                  # stessa operazione del passaggio precedente, cambia solo book_id per ISBN come identificatore dei libri
# Out:
# book_id
# 2     5.0
# 5     4.0
# 8     4.0
# 13    4.0
# 14    5.0
# Name: rating, dtype: float64

# %%
pd.merge(Goodbooks, medie2, how = 'inner', left_on = 'book_id', right_on = 'book_id')
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         2                  3             3   4640799          491
# 1         5               4671          4671    245494         1356
# 2         8               5107          5107   3036731          360
# 3        13               5470          5470    153313          995
# 4        14               7613          7613   2207778          896
# 5        18                  5             5   2402163          376
# 6        21                  2             2   2809203          307
# 7        23              15881         15881   6231171          398
# 8        24                  6             6   3046572          332
# 9        26                968           968   2982101          350
# 10       27                  1             1  41335427          275
# 11       28               7624          7624   2766512          458
# 12       32                890           890     40283          373
# ...

# %% [markdown]
# ### 4. Merge together all rows sharing the same book title, author and publisher. We will call the resulting datset merged books. The books that have not been merged together will not appear in merged books.

# %%
merged_books = Books[Books.duplicated(['Book-Title','Book-Author','Publisher'])]
merged_books                         # tutte le obs con almeno due tuple ('Book-Title','Book-Author','Publisher') in comune
# Out:
#               ISBN                                         Book-Title  \
# 654     0679893105    The Golden Compass (His Dark Materials, Book 1)
# 749     0446525502                                         The Rescue
# 886     0451205421                               The Door to December
# 1451    0385508417                                 Skipping Christmas
# 1565    0452284481                 Le Divorce (William Abrahams Book)
# ...            ...                                                ...
# 271142  0671648497                             Old Patagonian Express
# 271168  0395647398     The Two Towers (The Lord of the Rings, Part 2)
# 271171  0553234102                                    R Is for Rocket
# 271222  0451625145  Thirteen Days: A Memoir of the Cuban Missile C...
# 271245  0195124995  For Cause and Comrades: Why Men Fought in the ...
#
#                Book-Author Year-Of-Publication                      Publisher  \
# ...

# %%
merged_books = merged_books.drop_duplicates(subset=['Book-Title','Book-Author','Publisher'])
merged_books                          # delle obs trovate al passaggio precedente, se ne prende una per ogni tupla 
                                      # (rimuovo i duplicati in base a 'Book-Title','Book-Author','Publisher')
# Out:
#               ISBN                                         Book-Title  \
# 654     0679893105    The Golden Compass (His Dark Materials, Book 1)
# 749     0446525502                                         The Rescue
# 886     0451205421                               The Door to December
# 1451    0385508417                                 Skipping Christmas
# 1565    0452284481                 Le Divorce (William Abrahams Book)
# ...            ...                                                ...
# 271133  0451520521                                            Babbitt
# 271168  0395647398     The Two Towers (The Lord of the Rings, Part 2)
# 271171  0553234102                                    R Is for Rocket
# 271222  0451625145  Thirteen Days: A Memoir of the Cuban Missile C...
# 271245  0195124995  For Cause and Comrades: Why Men Fought in the ...
#
#                Book-Author Year-Of-Publication                      Publisher  \
# ...

# %% [markdown]
# ### 5. For each book in merged books compute its average rating.

# %%
Books2 = pd.merge(Books_Ratings, Books, how = 'inner', left_on = 'ISBN', right_on = 'ISBN')
Books2                # inner join per ottenere tutte le valutazioni date a libri contenuti in Books
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276725  034545104X            0
# 1          2313  034545104X            5
# 2          6543  034545104X            0
# 3          8680  034545104X            5
# 4         10314  034545104X            9
# ...         ...         ...          ...
# 179086   250750  1552790207            8
# 179087   250750  1567920950            0
# 179088   250750  1587990008            0
# 179089   250764  002736660X            0
# 179090   250764  048623715X            0
#
#                                                Book-Title  \
# 0                                    Flesh Tones: A Novel
# 1                                    Flesh Tones: A Novel
# 2                                    Flesh Tones: A Novel
# 3                                    Flesh Tones: A Novel
# 4                                    Flesh Tones: A Novel
# ...                                                   ...
# ...

# %%
medie3 = Books2.groupby(['Book-Title','Book-Author','Publisher'])['Book-Rating'].mean()
medie3.head()                             # media dei Book-Rating dei libri dell'insieme di valutazioni trovato in precedenza: 
                                          # media fatta in base alla tupla 'Book-Title','Book-Author','Publisher'
# Out:
# Book-Title                                                                                        Book-Author        Publisher
#  Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth  Elizabeth Roberts  HarperSanFrancisco                   5.555556
#  Final Fantasy Anthology: Official Strategy Guide (Brady Games)                                   David Cassady      BradyGames                           5.000000
#  Flight of Fancy: American Heiresses (Zebra Ballad Romance)                                       Tracy Cozzens      Kensington Publishing Corporation    4.000000
#  Little Comic Shop of Horrors (Give Yourself Goosebumps, Book 17)                                 R. L. Stine        Apple (Scholastic)                   0.000000
#  Mystery Mile                                                                                     Margery Allingham  Yestermorrow Inc                     0.000000
# Name: Book-Rating, dtype: float64

# %%
pd.merge(merged_books, medie3, how = 'inner', left_on = ['Book-Title','Book-Author','Publisher'], right_on = ['Book-Title','Book-Author','Publisher'])
# per considerare solo i libri contenuti in merged_books
# Out:
#             ISBN                                       Book-Title  \
# 0     0679893105  The Golden Compass (His Dark Materials, Book 1)
# 1     0425098680                Dinner at the Homesick Restaurant
# 2     0449212858                                    Rutland Place
# 3     1573228214                                    High Fidelity
# 4     034531798X       Foundation (Foundation Novels (Paperback))
# ...          ...                                              ...
# 1554  1564022137                                       Noah's Ark
# 1555  0151000980                              The Following Story
# 1556  039304632x                        The Voyage of the Narwhal
# 1557  158243123X                             A Student of Weather
# 1558  0395647398   The Two Towers (The Lord of the Rings, Part 2)
#
#            Book-Author Year-Of-Publication                      Publisher  \
# 0       PHILIP PULLMAN                1998  Knopf Books for Young Readers
# ...

# %% [markdown]
# ### 6. For each book in merged books compute the minimum and maximum of the average ratings over all corresponding books in the books dataset.

# %%
Books3 = pd.merge(Books, medie, how = 'inner', left_on = 'ISBN', right_on = 'ISBN')
Books3                      # per unire ai libri di Books tutte le medie trovate al passaggio n°2.
# Out:
#              ISBN                                         Book-Title  \
# 0      074322678X            Where You'll Find Me: And Other Stories
# 1      080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2      1552041778                                           Jane Doe
# 3      1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4      1567407781       The Witchfinder (Amos Walker Mystery Series)
# ...           ...                                                ...
# 67369  8401424828                                 Hija de Homero, La
# 67370  1565120752                                       Winter Birds
# 67371  067167806X  From Winchester to Cedar Creek: The Shenandoah...
# 67372  1561709085  Inner Peace for Busy People: Simple Strategies...
# 67373  8874960018           L'Occhio Nero Al Panda Gliel'ho Fatto IO
#
#                  Book-Author Year-Of-Publication  \
# 0                Ann Beattie                2002
# ...

# %%
minimi = Books3.groupby(['Book-Title','Book-Author','Publisher'])['Book-Rating'].min()
pd.merge(merged_books, minimi, how = 'inner', left_on = ['Book-Title','Book-Author','Publisher'], right_on = ['Book-Title','Book-Author','Publisher'])
# per trovare, tra le medie di ogni tupla 'Book-Title','Book-Author','Publisher', la minima, e di queste, considerare 
# solo quelle contenute in merged_books
# Out:
#             ISBN                                       Book-Title  \
# 0     0679893105  The Golden Compass (His Dark Materials, Book 1)
# 1     0425098680                Dinner at the Homesick Restaurant
# 2     0449212858                                    Rutland Place
# 3     1573228214                                    High Fidelity
# 4     034531798X       Foundation (Foundation Novels (Paperback))
# ...          ...                                              ...
# 1554  1564022137                                       Noah's Ark
# 1555  0151000980                              The Following Story
# 1556  039304632x                        The Voyage of the Narwhal
# 1557  158243123X                             A Student of Weather
# 1558  0395647398   The Two Towers (The Lord of the Rings, Part 2)
#
#            Book-Author Year-Of-Publication                      Publisher  \
# 0       PHILIP PULLMAN                1998  Knopf Books for Young Readers
# ...

# %%
massimi = Books3.groupby(['Book-Title','Book-Author','Publisher'])['Book-Rating'].max()
pd.merge(merged_books, massimi, how = 'inner', left_on = ['Book-Title','Book-Author','Publisher'], right_on = ['Book-Title','Book-Author','Publisher'])
# per trovare, tra le medie di ogni tupla 'Book-Title','Book-Author','Publisher', la massima, e di queste, considerare 
# solo quelle contenute in merged_books
# Out:
#             ISBN                                       Book-Title  \
# 0     0679893105  The Golden Compass (His Dark Materials, Book 1)
# 1     0425098680                Dinner at the Homesick Restaurant
# 2     0449212858                                    Rutland Place
# 3     1573228214                                    High Fidelity
# 4     034531798X       Foundation (Foundation Novels (Paperback))
# ...          ...                                              ...
# 1554  1564022137                                       Noah's Ark
# 1555  0151000980                              The Following Story
# 1556  039304632x                        The Voyage of the Narwhal
# 1557  158243123X                             A Student of Weather
# 1558  0395647398   The Two Towers (The Lord of the Rings, Part 2)
#
#            Book-Author Year-Of-Publication                      Publisher  \
# 0       PHILIP PULLMAN                1998  Knopf Books for Young Readers
# ...

# %% [markdown]
# ### 7. For each book in goodbooks, compute the list of its authors. Assuming that the number of reviews with a text (column work_text_reviews_count) is split equally among all authors, find for each authors the total number of reviews with a text. We will call this quantity the shared number of reviews with a text.

# %%
Goodbooks2 = Goodbooks
Goodbooks2['authors'].str.count(', ').max()
# ci sono al massimo 5 autori (quindi 4 virgole che li separano) nella colonna 'authors'
# Out:
# 4

# %%
Goodbooks2[['aut1','aut2','aut3','aut4','aut5']] = Goodbooks2['authors'].str.split(", ", n = 5, expand = True)
Goodbooks2                              #creo 5 colonne, dove aggiungere i potenziali autori singolarmente
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         1            2767052       2767052   2792775          272
# 1         2                  3             3   4640799          491
# 2         3              41865         41865   3212258          226
# 3         4               2657          2657   3275794          487
# 4         5               4671          4671    245494         1356
# ..      ...                ...           ...       ...          ...
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13                                    authors  \
# 0    439023483  9.780439e+12                            Suzanne Collins
# ...

# %%
diz={}
lista_autori=['aut1','aut2','aut3','aut4','aut5']
for elemento in range(0,99):
    if ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is None) & (Goodbooks2['aut3'][elemento] is None) & (Goodbooks2['aut4'][elemento] is None) & (Goodbooks2['aut5'][elemento] is None)):
        for autore in lista_autori:
            if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] = Goodbooks2['work_text_reviews_count'][elemento]
            elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] += Goodbooks2['work_text_reviews_count'][elemento]
    elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is None) & (Goodbooks2['aut4'][elemento] is None) & (Goodbooks2['aut5'][elemento] is None)):
        for autore in lista_autori:
            if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/2
            elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/2
    elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is not None) & (Goodbooks2['aut4'][elemento] is None) & (Goodbooks2['aut5'][elemento] is None)):
        for autore in lista_autori:
            if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/3
            elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/3
    elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is not None) & (Goodbooks2['aut4'][elemento] is not None) & (Goodbooks2['aut5'][elemento] is None)):
        for autore in lista_autori:
            if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/4
            elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/4
    elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is not None) & (Goodbooks2['aut4'][elemento] is not None) & (Goodbooks2['aut5'][elemento] is not None)):
        for autore in lista_autori:
            if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/5
            elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/5
diz

# per ogni obs, verifico quanti autori ci sono (vedendo quante celle delle colonne 'aut1','aut2','aut3','aut4','aut5' sono 
# None), per determinare tra quanti autori viene diviso il valore work_text_reviews_count di ogni obs.
# Dopo, verifico se l'autore è già inserito all'interno del dizionario diz (avente come chiavi i nomi degli autori, e come 
# valori il conteggio del totale di work_text_reviews_count), e quindi il conto dei work_text_reviews_count totali viene  
# aggiornato rispetto al valore già esistente, o se viene aggiunto il nuovo elemento in quanto non ancora presente.
# Out:
# {'Suzanne Collins': 340066,
#  'J.K. Rowling': 136668.0,
#  'Mary GrandPrÃ©': 136668.0,
#  'Stephenie Meyer': 258573,
#  'Harper Lee': 72586,
#  'F. Scott Fitzgerald': 51992,
#  'John Green': 230584,
#  'J.R.R. Tolkien': 52986,
#  'J.D. Salinger': 44920,
#  'Dan Brown': 66672,
#  'Jane Austen': 52994.0,
#  'Khaled Hosseini': 103375,
#  'Veronica Roth': 156896,
#  'George Orwell': 50644.666666666664,
#  'Erich Fromm': 15172.666666666666,
#  'CelÃ¢l Ã\x9cster': 15172.666666666666,
#  'Anne Frank': 6941.666666666667,
#  'Eleanor Roosevelt': 6941.666666666667,
#  'B.M. Mooyaart-Doubleday': 6941.666666666667,
#  'Stieg Larsson': 46983.0,
#  'Reg Keeland': 46983.0,
#  'Rufus Beck': 12033.0,
#  'Alice Sebold': 36642,
#  'William Golding': 26886,
#  'William Shakespeare': 7389.0,
#  'Robert           Jackson': 7389.0,
#  'Gillian Flynn': 121614,
#  'Kathryn Stockett': 78204,
#  'John Steinbeck': 24642,
#  'Arthur Golden': 25605,
#  'E.L. James': 128776,
#  'Paulo Coelho': 27890.5,
# ...

# %% [markdown]
# ### 8. For each year of publication, determine the author that has the largest value of the shared number of reviews with a text.

# %%
anni = Goodbooks['original_publication_year'].unique()
anni                             # ogni anno di pubblicazione originale contenuto nella 'colonna original_publication_year'
# Out:
# array([2008., 1997., 2005., 1960., 1925., 2012., 1937., 1951., 2000.,
#        1813., 2003., 2011., 1949., 1945., 1947., 2009., 1999., 1954.,
#        2010., 2002., 1998., 2007., 1595., 1988., 1993., 1950., 1996.,
#        2006., 1868., 1847., 2001., 1953., 1974., 1979., 1932., 1884.,
#        1952., 2015., 1995., 2004., 1969., 1936., 1985., 1818., 1977.,
#        1811., -720., 1946., 1859., 1990., 1964., 1989., 1958., 1973.,
#        1967., 1911., 1891., 1897.])

# %%
diz = {}
diz_anni = {}
for anno in anni:
    Goodbooks2 = Goodbooks[Goodbooks["original_publication_year"] == anno]
    indici = Goodbooks2.index
    for elemento in indici:
        if ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is None) & (Goodbooks2['aut3'][elemento] is None) & (Goodbooks2['aut4'][elemento] is None) & (Goodbooks2['aut5'][elemento] is None)):
            for autore in lista_autori:
                if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] = Goodbooks2['work_text_reviews_count'][elemento]
                elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] += Goodbooks2['work_text_reviews_count'][elemento]
        elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is None) & (Goodbooks2['aut4'][elemento] is None) & (Goodbooks2['aut5'][elemento] is None)):
            for autore in lista_autori:
                if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/2
                elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/2
        elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is not None) & (Goodbooks2['aut4'][elemento] is None) & (Goodbooks2['aut5'][elemento] is None)):
            for autore in lista_autori:
                if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/3
                elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/3
        elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is not None) & (Goodbooks2['aut4'][elemento] is not None) & (Goodbooks2['aut5'][elemento] is None)):
            for autore in lista_autori:
                if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/4
                elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/4
        elif ((Goodbooks2['aut1'][elemento] is not None) & (Goodbooks2['aut2'][elemento] is not None) & (Goodbooks2['aut3'][elemento] is not None) & (Goodbooks2['aut4'][elemento] is not None) & (Goodbooks2['aut5'][elemento] is not None)):
            for autore in lista_autori:
                if ((Goodbooks2[autore][elemento] not in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] = (Goodbooks2['work_text_reviews_count'][elemento])/5
                elif ((Goodbooks2[autore][elemento] in diz) & (Goodbooks2[autore][elemento] is not None)):
                    diz[(Goodbooks2[autore][elemento])] += (Goodbooks2['work_text_reviews_count'][elemento])/5
    max_key = max(diz, key=diz.get)
    all_values = diz.values()
    max_value = max(all_values)
    diz_anni[anno] = (max_key, max_value)
    diz={}
diz_anni

# per ogni anno, creo un dizionario provvisorio, che raccoglie i valori work_text_reviews_count di ogni autore in quell'anno,
# raccolti con lo stesso metodo del punto n°7. Poi, trovato il valore massimo di work_text_reviews_count di quell'anno, viene
# inserito questo valore nel dizionario diz_anni, dove ogni chiave è l'anno e l'elemento corrispondente è la tupla formata da 
# autore col valore massimo di work_text_reviews_count per quell'anno, e il numero di work_text_reviews_count.
# Out:
# {2008.0: ('Suzanne Collins', 155254),
#  1997.0: ('J.K. Rowling', 37933.5),
#  2005.0: ('Stephenie Meyer', 95009),
#  1960.0: ('Harper Lee', 72586),
#  1925.0: ('F. Scott Fitzgerald', 51992),
#  2012.0: ('John Green', 140739),
#  1937.0: ('J.R.R. Tolkien', 37653),
#  1951.0: ('J.D. Salinger', 44920),
#  2000.0: ('Dan Brown', 25112),
#  1813.0: ('Jane Austen', 49152),
#  2003.0: ('Khaled Hosseini', 59730),
#  2011.0: ('E.L. James', 103489),
#  1949.0: ('George Orwell', 15172.666666666666),
#  1945.0: ('George Orwell', 35472),
#  1947.0: ('Anne Frank', 6941.666666666667),
#  2009.0: ('Suzanne Collins', 88538),
#  1999.0: ('Stephen Chbosky', 47116),
#  1954.0: ('William Golding', 26886),
#  2010.0: ('Suzanne Collins', 96274),
#  2002.0: ('Alice Sebold', 36642),
#  1998.0: ('J.K. Rowling', 17086.0),
#  2007.0: ('Cassandra Clare', 51589),
#  1595.0: ('William Shakespeare', 7389.0),
#  1988.0: ('Paulo Coelho', 27890.5),
#  1993.0: ('Lois Lowry', 54084),
#  1950.0: ('C.S. Lewis', 15186),
# ...

# %% [markdown]
# ### 9. Assuming that there are no errors in the ISBN fields, find the books in both datasets, and compute the difference of average rating according to the ratings and the goodratings datasets

# %%
medie = Books_Ratings.groupby(['ISBN'])['Book-Rating'].mean()
medie_books = pd.merge(Books, medie, how = 'inner', left_on = 'ISBN', right_on = 'ISBN')
medie_books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  074322678X            Where You'll Find Me: And Other Stories
# 1  080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2  1552041778                                           Jane Doe
# 3  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4  1567407781       The Witchfinder (Amos Walker Mystery Series)
#
#          Book-Author Year-Of-Publication                 Publisher  \
# 0        Ann Beattie                2002                  Scribner
# 1         Adam Lebor                2000             Citadel Press
# 2       R. J. Kaiser                1999                Mira Books
# 3      Jack Canfield                1998     Health Communications
# 4  Loren D. Estleman                1998  Brilliance Audio - Trade
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/074322678X.0...
# 1  http://images.amazon.com/images/P/080652121X.0...
# ...

# %%
medie2 = Goodbooks_Ratings.groupby(['book_id'])['rating'].mean()
medie_goodbooks = pd.merge(Goodbooks, medie2, how = 'inner', left_on = 'book_id', right_on = 'book_id')
medie_goodbooks.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        2                  3             3  4640799          491  439554934
# 1        5               4671          4671   245494         1356  743273567
# 2        8               5107          5107  3036731          360  316769177
# 3       13               5470          5470   153313          995  451524934
# 4       14               7613          7613  2207778          896  452284244
#
#          isbn13                                    authors  \
# 0  9.780440e+12               J.K. Rowling, Mary GrandPrÃ©
# 1  9.780743e+12                        F. Scott Fitzgerald
# 2  9.780317e+12                              J.D. Salinger
# 3  9.780452e+12  George Orwell, Erich Fromm, CelÃ¢l Ãster
# 4  9.780452e+12                              George Orwell
#
#    original_publication_year                            original_title  ...  \
# ...

# %%
diff_medie = pd.merge(medie_goodbooks, medie_books, how = 'inner', left_on = 'isbn', right_on = 'ISBN')
diff_medie['diff_medie'] = diff_medie['rating'] - diff_medie['Book-Rating']
diff_medie               # è stato trovato solo un libro che appartiene sia a Books che a Goodbooks
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count        isbn  \
# 0       18                  5             5  2402163          376  043965548X
#
#          isbn13                                   authors  \
# 0  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©, Rufus Beck
#
#    original_publication_year                            original_title  ...  \
# 0                     1999.0  Harry Potter and the Prisoner of Azkaban  ...
#
#          ISBN                                         Book-Title  \
# 0  043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
#
#     Book-Author  Year-Of-Publication              Publisher  \
# 0  J.K. Rowling                 2004  Scholastic Paperbacks
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/043965548X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/043965548X.0...
#
# ...

# %% [markdown]
# ### 10. Split the users dataset according to the age. One dataset contains the users with unknown age, one with age 0-14, one with age 15-24, one with age 25-34, and so on.

# %%
Users['Age'].unique()               # tutti i possibili valori che assume la variabile 'Age' nel dataframe Users.
# Out:
# array([ nan,  18.,  17.,  61.,  26.,  14.,  25.,  19.,  46.,  55.,  32.,
#         24.,  20.,  34.,  23.,  51.,  31.,  21.,  44.,  30.,  57.,  43.,
#         37.,  41.,  54.,  42.,  50.,  39.,  53.,  47.,  36.,  28.,  35.,
#         13.,  58.,  49.,  38.,  45.,  62.,  63.,  27.,  33.,  29.,  66.,
#         40.,  15.,  60.,   0.,  79.,  22.,  16.,  65.,  59.,  48.,  72.,
#         56.,  67.,   1.,  80.,  52.,  69.,  71.,  73.,  78.,   9.,  64.,
#        103., 104.,  12.,  74.,  75., 231.,   3.,  76.,  83.,  68., 119.,
#         11.,  77.,   2.,  70.,  93.,   8.,   7.,   4.,  81., 114., 230.,
#        239.,  10.,   5., 148., 151.,   6., 101., 201.,  96.,  84.,  82.,
#         90., 123., 244., 133.,  91., 128.,  94.,  85., 141., 110.,  97.,
#        219.,  86., 124.,  92., 175., 172., 209., 212., 237.,  87., 162.,
#        100., 156., 136.,  95.,  89., 106.,  99., 108., 210.,  88., 199.,
#        147., 168., 132., 159., 186., 152., 102., 116., 200., 115., 226.,
# ...

# %%
eta = list(range(15, 255, 10))
Users2 = Users.copy()
Users2['Age_range'] = 0
# viene creata una nuova variabile 'Age_range', in cui verrà inserito a che categoria d'età appartiene l'utente di quella riga

# %%
for riga in range(0,278858):
    for elemento in eta:
        if ((Users2['Age'].values[riga] >= elemento) & (Users2['Age'].values[riga] <= (elemento+9))):
            Users2['Age_range'].values[riga] = str(elemento)+str('-')+str(elemento+9)
        elif Users2['Age'].values[riga] <= 14:
            Users2['Age_range'][riga] = '0-14'
    if Users2['Age_range'].values[riga] == 0:
        Users2['Age_range'][riga] = 'Not Available'

Users2.head()

# per ogni riga del dataframe Users, si valuta in che range d'età può essere inserito (se in quelli >14, con la prima condizione,
# in quelli tra 0 e 14 anni con la seconda condizione, o in quelli con età non disponibile), e in base a questo viene aggiunto il
# valore nella colonna 'Age_range'
# Out:
# <ipython-input-35-b9f878052639>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Users2['Age_range'][riga] = 'Not Available'
# C:\Users\andre\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-35-b9f878052639>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Users2['Age_range'][riga] = '0-14'
# ...

# %%
Users_byage = Users2.groupby("Age_range")
Users_byage.first()                   # obs raggruppate per età, ogni fascia d'età è in un dataframe diverso
# Out:
#                User-ID                                   Location    Age  \
# Age_range
# 0-14                11             melbourne, victoria, australia   14.0
# 105-114           8330        newcastle, thenorth, united kingdom  114.0
# 115-124           3211    le mesnil saint denis, yvelines, france  119.0
# 125-134          24411                     pirkkala, n/a, finland  133.0
# 135-144          30590  cambridge, cambridgeshire, united kingdom  141.0
# 145-154          11326        johannesburg, gauteng, south africa  148.0
# 15-24                2                  stockton, california, usa   18.0
# 155-164          61104                        largo, florida, usa  162.0
# 165-174          48099                     genova, liguria, italy  172.0
# 175-184          45689                        wolwich, maine, usa  175.0
# 185-194         132668                    bucharest, n/a, romania  186.0
# 195-204          13273              harrisburg, pennsylvania, usa  201.0
# ...

# %%
Users_byage.get_group('0-14')
# esempio per richiamare un dataframe
# Out:
#         User-ID                           Location   Age               City  \
# 10           11     melbourne, victoria, australia  14.0          melbourne
# 18           19                          weston, ,  14.0             weston
# 40           41            santee, california, usa  14.0             santee
# 119         120    villeneuve d`ascq, nord, france  13.0  villeneuve d`ascq
# 219         220           bogota, bogota, colombia   0.0             bogota
# ...         ...                                ...   ...                ...
# 278574   278575  burnaby, british columbia, canada  14.0            burnaby
# 278582   278583              steele, missouri, usa  13.0             steele
# 278668   278669          spring hill, fl, hernando  13.0        spring hill
# 278751   278752        london, nova scotia, canada   9.0             london
# 278793   278794           st. paul, minnesota, usa  14.0           st. paul
#
#                   Region    Country Age_range
# ...

# %% [markdown]
# ### 11. Find the books that appear only in the goodbooks datasets.

# %%
lista_libri = Books['ISBN'].tolist()
lista_libri2 = Books_Ratings['ISBN'].tolist()
Goodbooks_Ratings2 = pd.merge(Goodbooks, Goodbooks_Ratings, how = 'inner', left_on = 'book_id', right_on = 'book_id')
lista_libri3 = Goodbooks_Ratings2['isbn'].tolist()
lista_libri_goodbooks = Goodbooks['isbn'].tolist()    # vengono considerati tutti i codici isbn dei dataset Books, Books_Ratings
                                                      # e Goodbooks_Ratings2 (creato dall'inner join con Goodbooks)

# %%
libri_unici = []
for elemento in lista_libri_goodbooks:
    if elemento not in lista_libri and elemento not in lista_libri2 and elemento not in lista_libri3:
        libri_unici.append(elemento)
libri_unici                                #in libri_unici vengono messi tutti i libri che non si trovano in quei dataset.
# Out:
# ['439023483',
#  '316015849',
#  '61120081',
#  '525478817',
#  '1416524797',
#  '62024035',
#  '307269752',
#  '439023491',
#  '439023513',
#  '316166685',
#  '545010225',
#  '297859382',
#  '399155341',
#  '1612130291',
#  '60764899',
#  '553588486',
#  '143038419',
#  '786838655',
#  '553816713',
#  '1565125606',
#  '307347974',
#  '316160199',
#  '1416914285',
#  '316160202',
#  '375826696',
#  '031606792X',
#  '1594633665',
#  '743454537',
#  '1594489505',
#  '7442912',
#  '316068047',
#  '142402516',
#  '307275558',
#  '143039954',
#  '074324754X',
#  '014241493X',
#  '385737947',
#  '61234001',
#  '517189607',
#  '345803507',
#  '393970124',
#  '307269981',
#  '1612130585']

# %% [markdown]
# ### 12. Assuming that each pair (author, title) identifies a book, for each book find the number of times it appears in the books dataset. Which books appear the most times?

# %%
Books.groupby(['Book-Title','Book-Author']).count().sort_values(by = ['ISBN'], ascending = False)
# vengono contati quanti libri, con stesso 'Book-Title' e 'Book-Author', ci sono nel dataframe Books. Ordinati da
# quello che appare più spesso a quello che appare meno spesso.
# Out:
#                                                           ISBN  \
# Book-Title                       Book-Author
# Little Women                     Louisa May Alcott          21
# Wuthering Heights                Emily Bronte               20
# Adventures of Huckleberry Finn   Mark Twain                 20
# Pride and Prejudice              Jane Austen                18
# The Secret Garden                Frances Hodgson Burnett    16
# ...                                                        ...
# Heritage of Hastur               Marion Zimmer Bradley       1
# Heritage of Music (4 Volume Set) Michael Raeburn             1
# Heritage of Shame                Meg Hutchinson              1
# Heritage of Stars                Clifford D. Simak           1
# Ã?Ã?thique en toc              Didier Daeninckx            1
#
#                                                           Year-Of-Publication  \
# Book-Title                       Book-Author
# ...

# %% [markdown]
# ### 13. Find the author with the highest average rating according to the goodbooks datasets.

# %%
Goodbooks_unito = pd.merge(Goodbooks_Ratings, Goodbooks, how = 'inner', left_on = 'book_id', right_on = 'book_id')
Goodbooks_unito                   # inner join tra il dataframe Goodbooks_Ratings e Goodbooks.
# Out:
#     user_id  book_id  rating  goodreads_book_id  best_book_id   work_id  \
# 0         2       26       4                968           968   2982101
# 1         4       26       3                968           968   2982101
# 2         2       33       4                930           929   1558965
# 3         4       33       3                930           929   1558965
# 4         4       70       4             375802        375802   2422333
# 5         4       18       5                  5             5   2402163
# 6         4       27       5                  1             1  41335427
# 7         4       21       5                  2             2   2809203
# 8         4        2       5                  3             3   4640799
# 9         4       23       5              15881         15881   6231171
# 10        4       24       5                  6             6   3046572
# 11        4       35       5                865           865   4835472
# ...

# %%
medie_5 = Goodbooks_unito.groupby(['authors'])['average_rating'].mean()
medie_5                            # media del valore di 'average_rating' in base a 'authors'
# Out:
# authors
# Aldous Huxley                                3.970
# Arthur Golden                                4.080
# Dan Brown                                    3.790
# Elie Wiesel, Marion Wiesel                   4.300
# F. Scott Fitzgerald                          3.890
# George Orwell                                3.870
# George Orwell, Erich Fromm, CelÃ¢l Ãster    4.140
# J.D. Salinger                                3.790
# J.K. Rowling, Mary GrandPrÃ©                 4.468
# J.K. Rowling, Mary GrandPrÃ©, Rufus Beck     4.530
# John Grisham                                 4.030
# John Steinbeck                               3.840
# Kurt Vonnegut Jr.                            4.060
# Lois Lowry                                   4.120
# Louisa May Alcott                            4.040
# Mark Twain, John Seelye, Guy Cardwell        3.800
# Markus Zusak                                 4.360
# Michael Crichton                             3.960
# ...

# %%
print(medie_5.idxmax(axis=0, skipna=True), medie_5.max())           # gli autori con la media più alta, e la media che hanno
# Out:
# J.K. Rowling, Mary GrandPrÃ©, Rufus Beck 4.53
